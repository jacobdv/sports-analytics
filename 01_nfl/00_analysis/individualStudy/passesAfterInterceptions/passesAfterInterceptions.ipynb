# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('weeks1and2.csv')

# %%
data['play_result'].value_counts()
# Out:
# cmp    29
# inc    12
# na      4
# int     3
# sk      2
# td      1
# Name: play_result, dtype: int64

# %%
data
# Out:
#     week              player team opponent home team_record opponent_record  \
# 0      1           tom_brady   tb      dal   tb       0-0-0           0-0-0
# 1      1           tom_brady   tb      dal   tb       0-0-0           0-0-0
# 2      1        dak_prescott  dal       tb   tb       0-0-0           0-0-0
# 3      1         zach_wilson  nyj      car  car       0-0-0           0-0-0
# 4      1        kyler_murray  ari      ten  ten       0-0-0           0-0-0
# 5      1      ryan_tannehill  ten      ari  ten       0-0-0           0-0-0
# 6      1          jared_goff  det       sf  det       0-0-0           0-0-0
# 7      1     trevor_lawrence  jax      hou  hou       0-0-0           0-0-0
# 8      1     trevor_lawrence  jax      hou  hou       0-0-0           0-0-0
# 9      1     trevor_lawrence  jax      hou  hou       0-0-0           0-0-0
# 10     1      justin_herbert  lac      was  was       0-0-0           0-0-0
# ...

# %%
completions = data.loc[data['play_result'] == 'cmp']
completions['play_yardage'] = pd.to_numeric(completions['play_yardage'], errors='ignore')
average_yardage = round(np.average(completions['play_yardage'].loc[completions['play_yardage'] != 'na']), 1)
# Out:
# C:\Users\mrjac\Anaconda3\envs\sportsAnalytics\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
average_yardage
# Out:
# 8.8
