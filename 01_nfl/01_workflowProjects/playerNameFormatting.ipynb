# %%
import pandas as pd
file = 'data/2021/passing.csv'

# %%
def formatNames(player):
    if '*' in player:
        player = player.split('*')[0]
    else:
        player = player.split('\\')[0]
    return player

data = pd.read_csv(file)
data['Player'] = list(map(formatNames, list(data['Player'])))
data = data.drop(data.columns[0], axis=1)
data
# Out:
#       Rk                 Player   Tm  Age  Pos   G  GS   QBrec  Cmp  Att  ...  \
# 0      1              Tom Brady  TAM   44   QB  17  17  13-4-0  485  719  ...
# 1      2         Justin Herbert  LAC   23   QB  17  17   9-8-0  443  672  ...
# 2      3       Matthew Stafford  LAR   33   QB  17  17  12-5-0  404  601  ...
# 3      4        Patrick Mahomes  KAN   26   QB  17  17  12-5-0  436  658  ...
# 4      5             Derek Carr  LVR   30   QB  17  17  10-7-0  428  626  ...
# ..   ...                    ...  ...  ...  ...  ..  ..     ...  ...  ...  ...
# 110  111  Cordarrelle Patterson  ATL   30   RB  16  13     NaN    0    1  ...
# 111  112           Brett Rypien  DEN   25  NaN   1   0     NaN    0    2  ...
# 112  113          D'Andre Swift  DET   22   rb  13   4     NaN    0    1  ...
# 113  114          Albert Wilson  MIA   29   wr  14   5     NaN    0    1  ...
# 114  115        Brandon Zylstra  CAR   28   wr  13   3     NaN    0    1  ...
#
# ...

# %%
data.to_csv(file)
