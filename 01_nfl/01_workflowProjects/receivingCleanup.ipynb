# %%
import pandas as pd
import csv

# %%
a = pd.read_csv('data/2021/receiving.csv')
a
# Out:
#       Rk                      Player   Tm  Age  Pos   G  GS  Tgt  Rec   Ctch%  \
# 0      1      Cooper Kupp*+\KuppCo00  LAR   28   WR  17  17  191  145   75.9%
# 1      2    Davante Adams*+\AdamDa01  GNB   29   WR  16  16  169  123   72.8%
# 2      3       Tyreek Hill*\HillTy00  KAN   27   WR  17  16  159  111   69.8%
# 3      4  Justin Jefferson*\JeffJu00  MIN   22   WR  17  17  167  108   64.7%
# 4      5     Mark Andrews*+\AndrMa00  BAL   26   te  17   9  153  107   69.9%
# ..   ...                         ...  ...  ...  ...  ..  ..  ...  ...     ...
# 506  507  Christian Wilkins\WilkCh00  MIA   26   DT  17  17    1    1  100.0%
# 507  508      Seth Williams\WillSe00  DEN   21   wr   2   1    1    1  100.0%
# 508  509  Trayveon Williams\WillTr06  CIN   24  NaN   5   0    2    1   50.0%
# 509  510      Easop Winston\WinsEa00  NOR   25  NaN   3   1    1    1  100.0%
# 510  511        Deon Yelder\YeldDe00  TAM   26  NaN   5   0    1    1  100.0%
#
# ...
